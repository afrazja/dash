# %% [markdown]
# <a href="https://colab.research.google.com/github/afrazja/dash/blob/main/Ploty_%26_Dash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import plotly.offline as pyo
import plotly.graph_objs as go
import plotly.express as px

# %% [markdown]
# # New Section

# %%
np.random.seed(42)

# %%
random_x=np.random.randint(1,101,100)
random_y=np.random.randint(1,101,100)

# %%
from pandas._libs.hashtable import mode
data=[go.Scatter(x=random_x,y=random_y,mode='markers')]

# %%
pyo.plot(data,filename='asd.html')
# Out:
# 'asd.html'

# %%
df=pd.read_csv("/content/Life_Expectancy_Coursera.csv")

# %%
df
# Out:
#       Year      Status  Life expectancy   Adult Mortality  infant deaths  \
# 0     2015  Developing              65.0            263.0             62
# 1     2014  Developing              59.9            271.0             64
# 2     2013  Developing              59.9            268.0             66
# 3     2012  Developing              59.5            272.0             69
# 4     2011  Developing              59.2            275.0             71
# ...    ...         ...               ...              ...            ...
# 2933  2004  Developing              44.3            723.0             27
# 2934  2003  Developing              44.5            715.0             26
# 2935  2002  Developing              44.8             73.0             25
# 2936  2001  Developing              45.3            686.0             25
# 2937  2000  Developing              46.0            665.0             24
#
#       Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# ...

# %%
fig = px.line(df, x="Year", y="Life expectancy ", title='Life expectancy')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df=pd.read_csv('/content/nst-est2017-alldata.csv')
df.head()
df.set_index('NAME',inplace=True)

# %%
df2=df[df['DIVISION']=='1']
list_of_pop_col=[ col for col in df2.columns if col.startswith('POP') ]
df2=df2[list_of_pop_col]
df2
# Out:
#                POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# NAME
# Connecticut          3580171.0        3591927.0        3597705.0
# Maine                1327568.0        1327968.0        1328101.0
# Massachusetts        6564943.0        6612178.0        6659627.0
# New Hampshire        1316700.0        1318345.0        1320923.0
# Rhode Island         1053169.0        1052154.0        1052761.0
# Vermont               625842.0         626210.0         625606.0
#
#                POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# NAME
# Connecticut          3602470.0        3600188.0        3593862.0
# Maine                1327975.0        1328903.0        1327787.0
# Massachusetts        6711138.0        6757925.0        6794002.0
# New Hampshire        1322622.0        1328684.0        1330134.0
# Rhode Island         1052784.0        1054782.0        1055916.0
# Vermont               626044.0         625665.0         624455.0
#
# ...

# %%
from plotly.graph_objs.scatter import marker
from os import name
data=[go.Scatter(x=df2.columns, y=df2.loc[name],mode='lines',name=name) for name in df2.index]
pyo.plot(data)
# Out:
# 'temp-plot.html'
